# %% [markdown]
# ## Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection  import train_test_split
from sklearn.cluster import KMeans

# %%
pip install scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from scipy.stats import zscore

# %% [markdown]
# ## Loading the Dataset

# %%
df=pd.read_csv("/content/technical_support_data-2.csv")

# %%
df.head()
# Out:
#                        PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 0   Temperature control not working          170                1.3
# 1  power chord does not tightly fit           12                2.0
# 2             Fan swing not working            5                1.0
# 3           Main switch does not on            3                2.0
# 4        Forgot mobile app password           45                2.3
#
#    Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 0              32             0.04              0.0                   75
# 1             150             0.01              0.5                    5
# 2              35             0.02              0.2                   90
# 3               8             0.01              0.7                    5
# 4              54             0.15              0.0                   99
#
#    Post_warranty_percent
# 0                     25
# 1                     95
# 2                     10
# ...

# %%
df.shape
# Out:
# (23, 8)

# %%
df
# Out:
#                                  PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 0             Temperature control not working          170                1.3
# 1            power chord does not tightly fit           12                2.0
# 2                       Fan swing not working            5                1.0
# 3                     Main switch does not on            3                2.0
# 4                  Forgot mobile app password           45                2.3
# 5                           AC stops abruptly           47                3.1
# 6            App hangs while entring commands           12                4.0
# 7         App takes a long time to initialize          165                1.2
# 8     Unable to connect the App to the device          321                1.0
# 9        Reinstalling the app hangs the phone           22                3.3
# 10       Mobile screen blanks on use of phone           23                4.3
# ...

# %%
df_new=df.drop("PROBLEM_TYPE", axis=1)

# %%
df_new
# Out:
#     no_of_cases  Avg_pending_calls  Avg_resol_time  recurrence_freq  \
# 0           170                1.3              32             0.04
# 1            12                2.0             150             0.01
# 2             5                1.0              35             0.02
# 3             3                2.0               8             0.01
# 4            45                2.3              54             0.15
# 5            47                3.1             132             0.30
# 6            12                4.0             154             0.02
# 7           165                1.2              32             0.03
# 8           321                1.0               5             0.21
# 9            22                3.3             140             0.14
# 10           23                4.3             143             0.21
# 11          230                1.3              23             0.02
# 12          193                1.2              33             0.03
# ...

# %%
df_new=df_new.apply(zscore)

# %%
df_new
# Out:
#     no_of_cases  Avg_pending_calls  Avg_resol_time  recurrence_freq  \
# 0      0.179429          -0.701207       -0.538351        -0.843188
# 1     -0.862176           0.027143        1.510857        -1.101765
# 2     -0.908323          -1.013357       -0.486253        -1.015573
# 3     -0.921508           0.027143       -0.955140        -1.101765
# 4     -0.644625           0.339294       -0.156296         0.104930
# 5     -0.631441           1.171694        1.198266         1.397818
# 6     -0.862176           2.108144        1.580322        -1.015573
# 7      0.146467          -0.805257       -0.538351        -0.929380
# 8      1.174886          -1.013357       -1.007238         0.622085
# 9     -0.796251           1.379794        1.337195         0.018738
# 10    -0.789659           2.420294        1.389294         0.622085
# 11     0.574975          -0.701207       -0.694647        -1.015573
# 12     0.331055          -0.805257       -0.520985        -0.929380
# ...

# %%
sns.pairplot(df_new,diag_kind='kde')

# %% [markdown]
# ## The Elbow Method

# %%
lst=[]
for i in range(1,11):
    kmodel=KMeans(n_clusters=i,n_init=15,max_iter=500)
    kmodel.fit(df_new)
    lst.append(kmodel.inertia_)

# %%
lst
# Out:
# [161.0,
#  111.06384705701419,
#  72.23755934211154,
#  54.47028345217127,
#  40.182135620751126,
#  28.574642243053418,
#  23.971285647439274,
#  20.31829392250255,
#  17.229120474030005,
#  14.492890174763662]

# %%
plt.plot(range(1,11),lst,marker='o')

# %%
from scipy.spatial.distance import cdist
clusters=range(1,10)
meanDistortions=[]

for k in clusters:
  model=KMeans(n_clusters=k)
  model.fit(df_new)
  prediction=model.predict(df_new)
  meanDistortions.append(sum(np.min(cdist(df_new, model.cluster_centers_, 'euclidean'), axis=1)) /df_new.shape[0])

# %%
meanDistortions
# Out:
# [2.5132186215720433,
#  2.011069807948648,
#  1.6368266300358518,
#  1.4794812660287997,
#  1.2361489945423794,
#  1.0620842732423292,
#  0.9815040637871222,
#  0.8754508110202014,
#  0.7716105178135051]

# %%
plt.plot(clusters,meanDistortions, 'bx-')
plt.xlabel("k")
plt.ylabel("Mean Distortions")
# Out:
# Text(0, 0.5, 'Mean Distortions')

# %% [markdown]
# ##### Two values are of importance here — distortion and inertia. Distortion is the average of the euclidean squared distance from the centroid of the respective clusters. Inertia is the sum of squared distances of samples to their closest cluster centre

# %% [markdown]
# #### Our potential candidates seem to be at k=3,5 and 6 so lets see which performs better

# %% [markdown]
# ## K=3

# %%
new_model=KMeans(3)
new_model.fit(df_new)
pred=new_model.predict(df_new)

# %%
df["Clusters"]=pred

# %%
pred
# Out:
# array([2, 1, 2, 1, 0, 0, 0, 2, 2, 0, 0, 1, 2, 0, 2, 2, 1, 2, 0, 2, 1, 1,
#        1], dtype=int32)

# %%
df.head()
# Out:
#                        PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 0   Temperature control not working          170                1.3
# 1  power chord does not tightly fit           12                2.0
# 2             Fan swing not working            5                1.0
# 3           Main switch does not on            3                2.0
# 4        Forgot mobile app password           45                2.3
#
#    Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 0              32             0.04              0.0                   75
# 1             150             0.01              0.5                    5
# 2              35             0.02              0.2                   90
# 3               8             0.01              0.7                    5
# 4              54             0.15              0.0                   99
#
#    Post_warranty_percent  Clusters
# 0                     25         2
# 1                     95         1
# ...

# %%
df[df["Clusters"]==0]
# Out:
#                             PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 4             Forgot mobile app password           45                2.3
# 5                      AC stops abruptly           47                3.1
# 6       App hangs while entring commands           12                4.0
# 9   Reinstalling the app hangs the phone           22                3.3
# 10  Mobile screen blanks on use of phone           23                4.3
# 13              AC remote does not  work           24                2.8
# 18          Factory settings not working           72                2.3
#
#     Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 4               54             0.15             0.00                   99
# 5              132             0.30             0.03                  100
# 6              154             0.02             0.05                  100
# 9              140             0.14             0.01                   95
# ...

# %%
df[df["Clusters"]==1]
# Out:
#                                  PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 1            power chord does not tightly fit           12                2.0
# 3                     Main switch does not on            3                2.0
# 11              Cluttered with popup messages          230                1.3
# 16               Motor noise from the system           390                1.0
# 20  Battery backup does not get fully charged           29                2.2
# 21           Battery does not last full 8 hrs           43                2.1
# 22             Fan speed varies at on its own           78                2.2
#
#     Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 1              150             0.01             0.50                    5
# 3                8             0.01             0.70                    5
# 11              23             0.02             0.00                   10
# ...

# %%
df[df["Clusters"]==2]
# Out:
#                                PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 0           Temperature control not working          170                1.3
# 2                     Fan swing not working            5                1.0
# 7       App takes a long time to initialize          165                1.2
# 8   Unable to connect the App to the device          321                1.0
# 12            AC controller sofware missing          193                1.2
# 14                   Remote Keys get stuck           450                1.0
# 15       Unable to operate menu from remote          520                1.0
# 17                   Freshner holder stuck           140                1.7
# 19                WIFI connectivity breaks           290                1.1
#
#     Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 0               32             0.04             0.00                   75
# ...

# %%
df["Clusters"].value_counts()
# Out:
# 2    9
# 1    7
# 0    7
# Name: Clusters, dtype: int64

# %% [markdown]
# ## K=5

# %%
new_model=KMeans(5)
new_model.fit(df_new)
pred=new_model.predict(df_new)

# %%
df["Clusters"]=pred

# %%
pred
# Out:
# array([1, 4, 1, 4, 1, 3, 3, 1, 0, 3, 3, 2, 1, 3, 0, 0, 2, 1, 3, 0, 2, 2,
#        2], dtype=int32)

# %%
df.head()
# Out:
#                        PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 0   Temperature control not working          170                1.3
# 1  power chord does not tightly fit           12                2.0
# 2             Fan swing not working            5                1.0
# 3           Main switch does not on            3                2.0
# 4        Forgot mobile app password           45                2.3
#
#    Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 0              32             0.04              0.0                   75
# 1             150             0.01              0.5                    5
# 2              35             0.02              0.2                   90
# 3               8             0.01              0.7                    5
# 4              54             0.15              0.0                   99
#
#    Post_warranty_percent  Clusters
# 0                     25         1
# 1                     95         4
# ...

# %%
df["Clusters"].value_counts()
# Out:
# 1    6
# 3    6
# 2    5
# 0    4
# 4    2
# Name: Clusters, dtype: int64

# %% [markdown]
# ## K=6

# %%
new_model=KMeans(6)
new_model.fit(df_new)
pred=new_model.predict(df_new)

# %%
df["Clusters"]=pred

# %%
pred
# Out:
# array([0, 2, 0, 2, 0, 1, 1, 0, 4, 1, 1, 5, 0, 1, 4, 4, 5, 0, 1, 4, 3, 3,
#        3], dtype=int32)

# %%
df.head()
# Out:
#                        PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 0   Temperature control not working          170                1.3
# 1  power chord does not tightly fit           12                2.0
# 2             Fan swing not working            5                1.0
# 3           Main switch does not on            3                2.0
# 4        Forgot mobile app password           45                2.3
#
#    Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 0              32             0.04              0.0                   75
# 1             150             0.01              0.5                    5
# 2              35             0.02              0.2                   90
# 3               8             0.01              0.7                    5
# 4              54             0.15              0.0                   99
#
#    Post_warranty_percent  Clusters
# 0                     25         0
# 1                     95         2
# ...

# %%
df["Clusters"].value_counts()
# Out:
# 0    6
# 1    6
# 4    4
# 3    3
# 2    2
# 5    2
# Name: Clusters, dtype: int64

# %% [markdown]
# ## Our model for k=3 works best for this case cause we can assign people efficiently for solving problems
